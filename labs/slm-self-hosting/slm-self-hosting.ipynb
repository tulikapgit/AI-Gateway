# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## SLM self hosting lab
# ![flow](../../images/slm-self-hosting.gif)
#
# Playground to try the self-hosted [phy-3 Small Language Model (SLM)](https://azure.microsoft.com/blog/introducing-phi-3-redefining-whats-possible-with-slms/) trough the [APIM self-hosted gateway](https://learn.microsoft.com/azure/api-management/self-hosted-gateway-overview) with OpenAI API compatibility.
#
# The Phi-3-Mini-4K-Instruct is a 3.8B parameters, lightweight, state-of-the-art open model trained with the Phi-3 datasets that includes both synthetic data and the filtered publicly available websites data with a focus on high-quality and reasoning dense properties. The model belongs to the Phi-3 family with the Mini version in two variants 4K and 128K which is the context length (in tokens) that it can support.
#
# The model has underwent a post-training process that incorporates both supervised fine-tuning and direct preference optimization for the instruction following and safety measures. When assessed against benchmarks testing common sense, language understanding, math, code, long context and logical reasoning, Phi-3 Mini-4K-Instruct showcased a robust and state-of-the-art performance among models with less than 13 billion parameters.
#
# The APIM self-hosted gateway is a containerized version of the default managed gateway. It's useful for scenarios such as placing gateways in the same environments where you host your APIs. Like in this experiment where we self-host the phi-3 API. This enable use cases where the SLM is running on-premises
#
# ### TOC
# - [0️⃣ Initialize notebook variables](#0)
# - [1️⃣ Create the Azure Resource Group](#1)
# - [2️⃣ Create deployment using 🦾 Bicep](#2)
# - [3️⃣ Get the deployment outputs](#3)
# - [4️⃣ Option 1: Run phy-3 API locally with docker](#3)
# - [4️⃣ Option 2: Run phy-3 API locally without a container](#3)
# - [5️⃣ Run the APIM self-hosted gateway with docker](#3)
# - [🧪 Test the API using a direct HTTP call](#requests)
# - [🧪 Test the API using the Azure OpenAI Python SDK](#sdk)
# - [🗑️ Clean up resources](#clean)
#
# ### Prerequisites
# - [Python 3.12 or later version](https://www.python.org/) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/cli/azure/install-azure-cli) installed
# - [An Azure Subscription](https://azure.microsoft.com/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access) or just enable the mock service
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/cli/azure/authenticate-azure-cli-interactively)
# - [Docker Desktop](https://www.docker.com/products/docker-desktop/)

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

deployment_name = "o4-mini"
#os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__resource_group_name = f"lab-{deployment_name}" # change the name to match your naming resource_group_location = "westeurope"
resource_group_name="apimkuberg"
resource_group_location = "swedencentral"
apim_resource_name = "apimkube1"
apim_resource_location = "swedencentral"
apim_resource_sku = "Developer"
openai_resources = [  ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "GlobalBatch"
openai_model_name = "o4-mini"
openai_model_version = "0613"
openai_deployment_name = "o4-mini"
openai_api_version = "2024-02-01"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/' + openai_api_version + '/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ {"name": "phi-3", "endpoint": "http://host.docker.internal:5000"} ] # this is the endpoint of the phy-3 API running locally

self_hosted_gateway_name = "self-hosted-gateway"

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location}
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Group ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())
# Out:
# ✅ Azure Resource Group  apimkuberg  created ⌚  11:55:31.570673

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")
elif len(mock_webapps) > 0:
    backend_id = mock_backend_pool if len(mock_webapps) > 1 else mock_webapps[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku},
    "selfHostedGatewayName": { "value": self_hosted_gateway_name}
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)
# Out:
# {
#   "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.Resources/deployments/o4-mini",
#   "location": null,
#   "name": "o4-mini",
#   "properties": {
#     "correlationId": "bbd29b41-a88a-4ac8-ab17-9c817b8d01b7",
#     "debugSetting": null,
#     "dependencies": [
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai",
#         "resourceGroup": "apimkuberg",
#         "resourceName": "apimkube1-n3sjnfamzi4so/openai",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           }
#         ],
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai/policies/policy",
#         "resourceGroup": "apimkuberg",
#         "resourceName": "apimkube1-n3sjnfamzi4so/openai/policy",
#         "resourceType": "Microsoft.ApiManagement/service/apis/policies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/subscriptions/openai-subscription",
#         "resourceGroup": "apimkuberg",
#         "resourceName": "apimkube1-n3sjnfamzi4so/openai-subscription",
#         "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/gateways/self-hosted-gateway",
#         "resourceGroup": "apimkuberg",
#         "resourceName": "apimkube1-n3sjnfamzi4so/self-hosted-gateway",
#         "resourceType": "Microsoft.ApiManagement/service/gateways"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/gateways/self-hosted-gateway",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so/self-hosted-gateway",
#             "resourceType": "Microsoft.ApiManagement/service/gateways"
#           }
#         ],
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/gateways/self-hosted-gateway/apis/openai",
#         "resourceGroup": "apimkuberg",
#         "resourceName": "apimkube1-n3sjnfamzi4so/self-hosted-gateway/openai",
#         "resourceType": "Microsoft.ApiManagement/service/gateways/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so",
#             "resourceGroup": "apimkuberg",
#             "resourceName": "apimkube1-n3sjnfamzi4so",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/backends/phi-3",
#         "resourceGroup": "apimkuberg",
#         "resourceName": "apimkube1-n3sjnfamzi4so/phi-3",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       }
#     ],
#     "duration": "PT31.7057709S",
#     "error": null,
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so",
#         "resourceGroup": "apimkuberg"
#       },
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai",
#         "resourceGroup": "apimkuberg"
#       },
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/apis/openai/policies/policy",
#         "resourceGroup": "apimkuberg"
#       },
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/backends/phi-3",
#         "resourceGroup": "apimkuberg"
#       },
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/gateways/self-hosted-gateway",
#         "resourceGroup": "apimkuberg"
#       },
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/gateways/self-hosted-gateway/apis/openai",
#         "resourceGroup": "apimkuberg"
#       },
#       {
#         "id": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so/subscriptions/openai-subscription",
#         "resourceGroup": "apimkuberg"
#       }
#     ],
#     "outputs": {
#       "apimResourceGatewayURL": {
#         "type": "String",
#         "value": "https://apimkube1-n3sjnfamzi4so.azure-api.net"
#       },
#       "apimResourceId": {
#         "type": "String",
#         "value": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so"
#       },
#       "apimResourceName": {
#         "type": "String",
#         "value": "apimkube1-n3sjnfamzi4so"
#       },
#       "apimServiceId": {
#         "type": "String",
#         "value": "/subscriptions/9f64891c-88e8-4651-83e3-58000743cd9f/resourceGroups/apimkuberg/providers/Microsoft.ApiManagement/service/apimkube1-n3sjnfamzi4so"
#       },
#       "apimSubscriptionKey": {
#         "type": "String",
#         "value": "2df5b63b210d4902b8c9bbeaa4e921f1"
#       }
#     },
#     "parameters": {
#       "apimPublisherEmail": {
#         "type": "String",
#         "value": "noreply@microsoft.com"
#       },
#       "apimPublisherName": {
#         "type": "String",
#         "value": "Microsoft"
#       },
#       "apimResourceLocation": {
#         "type": "String",
#         "value": "swedencentral"
#       },
#       "apimResourceName": {
#         "type": "String",
#         "value": "apimkube1"
#       },
#       "apimSku": {
#         "type": "String",
#         "value": "Developer"
#       },
#       "apimSkuCount": {
#         "type": "Int",
#         "value": 1
#       },
#       "mockBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI Mocking endpoints"
#       },
#       "mockBackendPoolName": {
#         "type": "String",
#         "value": "mock-backend-pool"
#       },
#       "mockWebApps": {
#         "type": "Array",
#         "value": [
#           {
#             "endpoint": "http://host.docker.internal:5000",
#             "name": "phi-3"
#           }
#         ]
#       },
#       "openAIAPIDescription": {
#         "type": "String",
#         "value": "Azure OpenAI API inferencing API"
#       },
#       "openAIAPIDisplayName": {
#         "type": "String",
#         "value": "OpenAI"
#       },
#       "openAIAPIName": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPIPath": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPISpecURL": {
#         "type": "String",
#         "value": "https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/2024-02-01/inference.json"
#       },
#       "openAIBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI endpoints"
#       },
#       "openAIBackendPoolName": {
#         "type": "String",
#         "value": "openai-backend-pool"
#       },
#       "openAIConfig": {
#         "type": "Array",
#         "value": []
#       },
#       "openAIDeploymentName": {
#         "type": "String",
#         "value": "o4-mini"
#       },
#       "openAIModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "openAIModelName": {
#         "type": "String",
#         "value": "o4-mini"
#       },
#       "openAIModelVersion": {
#         "type": "String",
#         "value": "0613"
#       },
#       "openAISku": {
#         "type": "String",
#         "value": "GlobalBatch"
#       },
#       "openAISubscriptionDescription": {
#         "type": "String",
#         "value": "OpenAI Subscription"
#       },
#       "openAISubscriptionName": {
#         "type": "String",
#         "value": "openai-subscription"
#       },
#       "selfHostedGatewayDescription": {
#         "type": "String",
#         "value": "Self-hosted API Gateway"
#       },
#       "selfHostedGatewayLocationCountryOrRegion": {
#         "type": "String",
#         "value": "Portugal"
#       },
#       "selfHostedGatewayLocationName": {
#         "type": "String",
#         "value": "Lisbon"
#       },
#       "selfHostedGatewayName": {
#         "type": "String",
#         "value": "self-hosted-gateway"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.ApiManagement",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "swedencentral"
#             ],
#             "properties": null,
#             "resourceType": "service",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/policies",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/subscriptions",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/gateways",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/gateways/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/backends",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "4042690306350436139",
#     "templateLink": null,
#     "timestamp": "2025-05-29T09:33:23.549592+00:00",
#     "validatedResources": null
#   },
#   "resourceGroup": "apimkuberg",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }
# WARNING: A new Bicep release is available: v0.35.1. Upgrade now by running "az bicep upgrade".
# WARNING: c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(120,21) : Warning BCP081: Resource type "Microsoft.CognitiveServices/accounts/deployments@2023-05-01" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(137,22) : Warning BCP081: Resource type "Microsoft.ApiManagement/service@2023-05-01-preview" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(166,14) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/apis@2023-05-01-preview" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(199,24) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(231,22) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(263,28) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(280,26) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\Users\tulikap\OneDrive - Microsoft\Fora\APIMSHG\AI-Gateway\labs\slm-self-hosting\main.bicep(297,27) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/subscriptions@2023-05-01-preview" does not have types available.
# 269

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs
#
# We are now at the stage where we only need to retrieve the gateway URL and the subscription before we are ready for testing.

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceName.value -o tsv
apim_config_endpoint = f"{deployment_stdout.n}.configuration.azure-api.net"
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceId.value -o tsv
apim_resource_id = deployment_stdout.n
uri = f"{apim_resource_id}/gateways/{self_hosted_gateway_name}/generateToken?api-version=2023-05-01-preview"
body = {
  "properties": {    
    "keyType": "primary",
    "expiry": (datetime.datetime.now() + datetime.timedelta(days=29)).isoformat()
  }
}
body_text = "\"" + json.dumps(body).replace("\"","\\\"") + "\""
cli_stdout = ! az rest --method POST --uri {uri} --body {body_text} -o tsv
self_hosted_gateway_auth = f"GatewayKey {cli_stdout.n}"
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
apim_resource_gateway_url = "http://localhost"
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)
# Out:
# 👉🏻 API Gateway URL:  http://localhost

# %% [markdown]
# <a id='41'></a>
# ### 4️⃣ Option 1: Run phy-3 API locally with docker
#
# The following commands will build the container image and then create a container instance to run it

# %%
! docker build -t phi-3 phy-3/.
! docker run -d -p 5000:5000 -v phi2-models:/model_cache phi-3
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 309B 0.0s done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.8-slim-buster
# #2 DONE 1.0s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/5] FROM docker.io/library/python:3.8-slim-buster@sha256:8799b0564103a9f36cfb8a8e1c562e11a9a6f2e3bb214e2adc23982b36a04511
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 94B done
# #5 DONE 0.0s
#
# #6 [4/5] RUN pip3 install --no-cache-dir -r requirements.txt
# #6 CACHED
#
# #7 [2/5] WORKDIR /usr/src/app
# #7 CACHED
#
# #8 [3/5] COPY requirements.txt ./
# #8 CACHED
#
# #9 [5/5] COPY . .
# #9 CACHED
#
# #10 exporting to image
# #10 exporting layers done
# #10 writing image sha256:1da951242208391e57a3c24fae816d33610670726ea4c808d50ae50cc43f939c done
# #10 naming to docker.io/library/phi-3 done
# #10 DONE 0.0s
# 5f9e9a1d84313cedc2167e5366fb8852b317253068896349b40056e79fbf115e

# %% [markdown]
# <a id='42'></a>
# ### 4️⃣ Option 2: Run phy-3 API locally without a container
#
# We recommend running the following commands in a separate terminal

# %%
! cd phy-3
! pip install --no-cache-dir -r requirements.txt
! flask --app app.py --debug run
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Usage: flask run [OPTIONS]
# Try 'flask run --help' for help.
#
# Error: Could not import 'app'.

# %% [markdown]
# <a id='5'></a>
# ### 5️⃣ Run the APIM self-hosted gateway with docker
#
# In a production environment we recommend using Kubernetes. Follow this [guide](https://learn.microsoft.com/azure/api-management/how-to-self-hosted-gateway-on-kubernetes-in-production) to run the APIM self-hosted gateway in production.

# %%
! docker run -d -p 80:8080 -p 443:8081 -e config.service.endpoint="{apim_config_endpoint}" -e config.service.auth="{self_hosted_gateway_auth}" -e runtime.deployment.artifact.source="Azure Portal" -e runtime.deployment.mechanism=Docker --name self_hosted_gateway_name mcr.microsoft.com/azure-api-management/gateway:v2
# Out:
# 96f974b52b5bd99a8e9fda15649aeb4e51cea0b3cdc7abbecaab4cf900aba8e3

# %% [markdown]
# <a id='requests'></a>
# ### 🧪 Test the API using a direct HTTP call
#
# Requests is an elegant and simple HTTP library for Python that will be used here to make raw API requests and inspect the responses.
#
# ⚠️ The requests might take some minutes depending on your running environment.

# %%
url = apim_resource_gateway_url + "/openai/deployments/" + openai_deployment_name + "/chat/completions?api-version=" + openai_api_version
messages={"messages":[
    {"role": "user", "content": "write me a poem about the moon"}
]}
response = requests.post(url, headers = {'api-key':apim_subscription_key}, json = messages)
print("status code: ", response.status_code)
print("headers ", response.headers)
print("x-ms-region: ", response.headers.get("x-ms-region")) # this header is useful to determine the region of the backend that served the request
if (response.status_code == 200):
    data = json.loads(response.text)
    print("response: ", data.get("choices")[0].get("message").get("content"))
else:
    print(response.text)
# Out:
# status code:  200
# headers  {'Content-Length': '997', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Tue, 03 Jun 2025 11:11:14 GMT', 'Server': 'Werkzeug/3.0.6 Python/3.8.17', 'x-ms-region': 'host.docker.internal'}
# x-ms-region:  host.docker.internal
# response:  <|user|> write me a poem about the moon<|end|><|assistant|> In the velvet night, a silver sphere,
#
# The moon ascends, a distant spear.
#
# It dances with the stars in a silent ballet,
#
# A beacon of light in the darkest of day.
#
#
# Its cratered face, a map of time,
#
# Whispers tales in a rhythm and rhyme.
#
# A guardian of the night, a watcher of dreams,
#
# The moon, in its glow, is a celestial beam.
#
#
# It waxes and wanes, a cycle of grace,
#
# A mirror to the sun, in the sky's embrace.
#
# In its phases, a story unfolds,
#
# Of ancient myths and legends untold.
#
#
# The moon, a muse for poets and sages,
#
# A symbol of beauty, through the ages.
#
# In its light

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Test the API using the Azure OpenAI Python SDK
# OpenAPI provides a widely used [Python library](https://github.com/openai/openai-python). The library includes type definitions for all request params and response fields. The goal of this test is to assert that APIM can seamlessly proxy requests to OpenAI without disrupting its functionality.
# - Note: run ```pip install openai``` in a terminal before executing this step.

# %%
from openai import AzureOpenAI
messages=[
    {"role": "user", "content": "write me a poem about the sea"}
]
client = AzureOpenAI(
    azure_endpoint=apim_resource_gateway_url,
    api_key=apim_subscription_key,
    api_version=openai_api_version
)
response = client.chat.completions.create(model=openai_model_name, messages=messages)
print(response.choices[0].message.content)
# Out:
# <|user|> write me a poem about the sea<|end|><|assistant|> Whispers of the Sea
#
#
# In the realm where the sky kisses the deep,
#
# The sea whispers secrets that it keeps.
#
# Its surface, a mirror to the sun,
#
# Reflecting the day and the night begun.
#
#
# Waves dance in rhythmic, timeless grace,
#
# Each crest and trough in an endless chase.
#
# The sea, a canvas of blues and greens,
#
# A world where the horizon meets.
#
#
# Beneath the waves, a world unseen,
#
# Where creatures glide in a silent scene.
#
# The sea, a cradle of life's embrace,
#
# Nurturing the heart of our blue space.
#
#
# The sea's song, a lullaby to the shore,
#
# A reminder of the wonders it bore.
#
# In its depths

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
